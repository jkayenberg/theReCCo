# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %% [markdown]
# # Import summer / winter results

# %%
# Import summer / winter results

with open("results/results_summer_highbatteryprice.csv", "r") as csvfile:
    results_summer = pd.read_csv(csvfile)

with open("results/results_winter_highbatteryprice.csv", "r") as csvfile:
    results_winter = pd.read_csv(csvfile)

results_summer = results_summer.sort_values("Price")

results_winter = results_winter.sort_values("Price")

# %% [markdown]
# # Plot price & success rate (summer)

# %%
# Plot price / success rate (summer)

fig, ax = plt.subplots(figsize=(8,4))

plt.scatter(results_summer["Price"], results_summer["Success rate"], color = "b", alpha = 0.4)

x = 1990
y = 1.0

x1 = 1490
y1 = 0.950232

plt.scatter(x, y, color='r', zorder=1)
plt.scatter(x1, y1, color='r', zorder=1)

plt.plot([0,5000],[0.95,0.95], color = "black", linewidth = 1.0)

ax.set_ylabel("Success rate")
ax.set_xlabel("Price [€]")

plt.gca().invert_yaxis()

plt.xlim([0,5000])

legend_elements = [Line2D([0], [0], color='black', lw=1, label='Threshold'),
                   Line2D([0], [0], marker = "o", color='w', label='Optimal solutions',
                          markerfacecolor='r', markersize=10)]

ax.legend(handles=legend_elements, loc='upper right')

plt.savefig('results/results_summer.png')

plt.show()

# %% [markdown]
# # Plot price & success rate (winter)

# %%
# Plot price / success rate (summer)

fig, ax = plt.subplots(figsize=(8,4))

plt.scatter(results_winter["Price"], results_winter["Success rate"], color = "b", alpha = 0.4)

x = 3490
y = 1.0

x2 = 2490
y2 = 0.952948

plt.scatter(x, y, color='r', zorder=1)
plt.scatter(x2, y2, color='r', zorder=1)

plt.plot([0,5000],[0.95,0.95], color = "black", linewidth = 1.0)

ax.set_ylabel("Success rate")
ax.set_xlabel("Price [€]")

plt.gca().invert_yaxis()

plt.xlim([0,5000])

legend_elements = [Line2D([0], [0], color='black', lw=1, label='Threshold'),
                   Line2D([0], [0], marker = "o", color='w', label='Optimal solutions',
                          markerfacecolor='r', markersize=10)]

ax.legend(handles=legend_elements, loc='upper right')

plt.savefig('results/results_winter.png')

plt.show()

# %% [markdown]
# # Winter / summer solar panel comparison plots

# %%
# Winter / summer solar panel comparison

fig, ax = plt.subplots(figsize=(8,4))

scatter = plt.scatter(results_winter["Panel count"], results_winter["Success rate"], color = "b")

xticks = [1,2,3]

ax.set_ylabel("Success rate (Winter)")
ax.set_xlabel("Panel count")
ax.set_xticks(xticks)

plt.xlim([0.9,3.1])

plt.savefig('results/summer_winter_solarpanel1.png')

fig2, ax2 = plt.subplots(figsize=(8,4))

scatter2 = plt.scatter(results_summer["Panel count"], results_summer["Success rate"], color = "r")

ax2.set_ylabel("Success rate (Summer)")
ax2.set_xlabel("Panel count")
ax2.set_xticks(xticks)

plt.xlim([0.9,3.1])

plt.savefig('results/summer_winter_solarpanel2.png')

plt.show()

# %% [markdown]
# # Energy sources / success rate plot (with winter data)

# %%
# Energy sources / success rate plot (with winter data)

results_winter_n = results_winter[results_winter["Windturbine size"] == "none"]
results_winter_s = results_winter[results_winter["Windturbine size"] == "small"]
results_winter_l = results_winter[results_winter["Windturbine size"] == "large"]

fig, ax = plt.subplots(figsize=(8,4))

plt.scatter(results_winter_n["Battery capacity"], results_winter_n["Success rate"], color = "b", s = (results_winter_n["Panel count"] + 1) * 30)
plt.scatter(results_winter_s["Battery capacity"], results_winter_s["Success rate"], color = "r", s = (results_winter_s["Panel count"] + 1) * 30)
plt.scatter(results_winter_l["Battery capacity"], results_winter_l["Success rate"], color = "g", s = (results_winter_l["Panel count"] + 1) * 30)

ax.set_ylabel("Success rate")
ax.set_xlabel("Battery capacity")

legend_elements = [Line2D([0], [0], marker = "o", color='w', label='Large windturbine',
                          markerfacecolor='g', markersize=10),
                   Line2D([0], [0], marker = "o", color='w', label='Small windturbine',
                          markerfacecolor='r', markersize=10),
                  Line2D([0], [0], marker = "o", color='w', label='No windturbine',
                          markerfacecolor='b', markersize=10),
                  Line2D([0], [0], color='w', label='Size = Panel count',
                          markerfacecolor='r', markersize=10)]

ax.legend(handles=legend_elements, loc='lower right')

plt.xlim([0,10000])

plt.savefig('results/energysources_successrate_winter.png')

plt.show()

# %% [markdown]
# # Energy sources / price plot (with winter data)

# %%
# Energy sources / price plot (with winter data)

results_winter_n = results_winter[results_winter["Windturbine size"] == "none"]
results_winter_s = results_winter[results_winter["Windturbine size"] == "small"]
results_winter_l = results_winter[results_winter["Windturbine size"] == "large"]

fig, ax = plt.subplots(figsize=(8,4))

plt.scatter(results_winter_n["Battery capacity"], results_winter_n["Price"], color = "b", s = (results_winter_n["Panel count"] + 1) * 30)
plt.scatter(results_winter_s["Battery capacity"], results_winter_s["Price"], color = "r", s = (results_winter_s["Panel count"] + 1) * 30)
plt.scatter(results_winter_l["Battery capacity"], results_winter_l["Price"], color = "g", s = (results_winter_l["Panel count"] + 1) * 30)

ax.set_ylabel("Price [€]")
ax.set_xlabel("Battery capacity")

legend_elements = [Line2D([0], [0], marker = "o", color='w', label='Large windturbine',
                          markerfacecolor='g', markersize=10),
                   Line2D([0], [0], marker = "o", color='w', label='Small windturbine',
                          markerfacecolor='r', markersize=10),
                  Line2D([0], [0], marker = "o", color='w', label='No windturbine',
                          markerfacecolor='b', markersize=10),
                  Line2D([0], [0], color='w', label='Size = Panel count',
                          markerfacecolor='r', markersize=10)]

ax.legend(handles=legend_elements, loc='lower right')

plt.xlim([0,10000])

plt.savefig('results/energysources_price_winter.png')

plt.show()

# %% [markdown]
# # Appendix: Find optimal solution (summer)

# %%
# Find optimal solution (summer)

i = results_summer.index
index = results_summer["Success rate"] > 0.95
optimal_result_s = i[index]
optimal_result_s.tolist()
print(optimal_result_s)

for i in optimal_result_s:
    display(results_summer.loc[[i]])
# Out:
# Int64Index([220, 201, 140, 221, 121, 202, 141, 222, 122, 203,
#             ...
#             159,  76,  57,  38,  77,  58,  39,  78,  59,  79],
#            dtype='int64', length=166)
#      Unnamed: 0  Panel count  Battery capacity Windturbine size   Price  \
# 220           0            3               500             none  1490.0
#
#      Success rate
# 220      0.950232
#      Unnamed: 0  Panel count  Battery capacity Windturbine size   Price  \
# 201           0            2              1000             none  1660.0
#
#      Success rate
# 201      0.980588
#      Unnamed: 0  Panel count  Battery capacity Windturbine size   Price  \
# 140           0            3               500            small  1890.0
#
#      Success rate
# 140      0.952149
#      Unnamed: 0  Panel count  Battery capacity Windturbine size   Price  \
# 221           0            3              1000             none  1990.0
#
#      Success rate
# 221           1.0
# ...

# %% [markdown]
# # Appendix: Find optimal solution (winter)

# %%
# Find optimal solution (winter)

i = results_winter.index
index = results_winter["Success rate"] > 0.95
optimal_result_w = i[index]
optimal_result_w.tolist()
print(optimal_result_w)

for i in optimal_result_w:
    display(results_winter.loc[[i]])
# Out:
# Int64Index([222, 142, 223, 143, 224, 205, 144, 225, 125, 206,
#             ...
#             159,  76,  57,  38,  77,  58,  39,  78,  59,  79],
#            dtype='int64', length=131)
#      Unnamed: 0  Panel count  Battery capacity Windturbine size   Price  \
# 222           0            3              1500             none  2490.0
#
#      Success rate
# 222      0.952948
#      Unnamed: 0  Panel count  Battery capacity Windturbine size   Price  \
# 142           0            3              1500            small  2890.0
#
#      Success rate
# 142      0.956622
#      Unnamed: 0  Panel count  Battery capacity Windturbine size   Price  \
# 223           0            3              2000             none  2990.0
#
#      Success rate
# 223      0.994967
#      Unnamed: 0  Panel count  Battery capacity Windturbine size   Price  \
# 143           0            3              2000            small  3390.0
#
#      Success rate
# 143       0.99968
# ...
